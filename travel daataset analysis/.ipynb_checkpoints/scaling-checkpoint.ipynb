# %% [markdown]
# # Scalling (for numerical data)

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('no_outliers/data_nooutliers1.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  CustomerID  ProdTaken   Age    TypeofContact  \
# 0             0           0      200000          1  41.0     Self Enquiry
# 1             1           1      200001          0  49.0  Company Invited
# 2             2           2      200002          1  37.0     Self Enquiry
# 3             3           3      200003          0  33.0  Company Invited
# 4             4           4      200004          0  32.0     Self Enquiry
#
#    CityTier  DurationOfPitch      Occupation  Gender  ...  ProductPitched  \
# 0         3              6.0        Salaried  Female  ...          Deluxe
# 1         1             14.0        Salaried    Male  ...          Deluxe
# 2         1              8.0     Free Lancer    Male  ...           Basic
# 3         1              9.0        Salaried  Female  ...           Basic
# 4         1              8.0  Small Business    Male  ...           Basic
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips Passport  \
# 0                    3.0        Single            1.0        1
# 1                    4.0      Divorced            2.0        0
# 2                    3.0        Single            7.0        1
# 3                    3.0      Divorced            2.0        1
# 4                    4.0      Divorced            1.0        0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  Designation  \
# 0                       2       1                       0.0      Manager
# 1                       3       1                       2.0      Manager
# 2                       3       0                       0.0    Executive
# 3                       5       1                       1.0    Executive
# 4                       5       1                       0.0    Executive
#
#    MonthlyIncome
# 0        20993.0
# 1        20130.0
# 2        17090.0
# 3        17909.0
# 4        18468.0
#
# [5 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'CustomerID', 'ProdTaken', 'Age',
#        'TypeofContact', 'CityTier', 'DurationOfPitch', 'Occupation', 'Gender',
#        'NumberOfPersonVisiting', 'NumberOfFollowups', 'ProductPitched',
#        'PreferredPropertyStar', 'MaritalStatus', 'NumberOfTrips', 'Passport',
#        'PitchSatisfactionScore', 'OwnCar', 'NumberOfChildrenVisiting',
#        'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
data.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'],axis=1,inplace=True)

# %%
data
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0  32.0     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4874      204883          1  49.0     Self Enquiry         3              9.0
# 4875      204884          1  28.0  Company Invited         1             31.0
# 4876      204885          1  52.0     Self Enquiry         3             17.0
# 4877      204886          1  19.0     Self Enquiry         3             16.0
# 4878      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# 1           Salaried    Male                       3                4.0
# 2        Free Lancer    Male                       3                4.0
# 3           Salaried  Female                       2                3.0
# 4     Small Business    Male                       2                3.0
# ...              ...     ...                     ...                ...
# 4874  Small Business    Male                       3                5.0
# 4875        Salaried    Male                       4                5.0
# 4876        Salaried  Female                       4                4.0
# 4877  Small Business    Male                       3                4.0
# 4878        Salaried    Male                       4                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                    3.0        Single            1.0
# 1            Deluxe                    4.0      Divorced            2.0
# 2             Basic                    3.0        Single            7.0
# 3             Basic                    3.0      Divorced            2.0
# 4             Basic                    4.0      Divorced            1.0
# ...             ...                    ...           ...            ...
# 4874         Deluxe                    4.0     Unmarried            2.0
# 4875          Basic                    3.0        Single            3.0
# 4876       Standard                    4.0       Married            7.0
# 4877          Basic                    3.0        Single            3.0
# 4878          Basic                    4.0     Unmarried            3.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                       0.0
# 1            0                       3       1                       2.0
# 2            1                       3       0                       0.0
# 3            1                       5       1                       1.0
# 4            0                       5       1                       0.0
# ...        ...                     ...     ...                       ...
# 4874         1                       1       1                       1.0
# 4875         1                       3       1                       2.0
# 4876         0                       1       1                       3.0
# 4877         0                       5       0                       2.0
# 4878         1                       3       1                       2.0
#
#          Designation  MonthlyIncome
# 0            Manager        20993.0
# 1            Manager        20130.0
# 2          Executive        17090.0
# 3          Executive        17909.0
# 4          Executive        18468.0
# ...              ...            ...
# 4874         Manager        26576.0
# 4875       Executive        21212.0
# 4876  Senior Manager        31820.0
# 4877       Executive        20289.0
# 4878       Executive        24041.0
#
# [4879 rows x 20 columns]

# %% [markdown]
# ## Scaling Methods:
# 1. Absolute Maximum Scaling
# 2. Min-Max Scaling
# 3. Normalization
# 4. Standardization
# 5. Robust Scaling

# %%
data['CityTier'] = data['CityTier'].astype('O')
data['NumberOfPersonVisiting'] = data['CityTier'].astype('O')
data['PreferredPropertyStar'] = data['CityTier'].astype('O')
data['Passport'] = data['CityTier'].astype('O')
data['PitchSatisfactionScore'] = data['CityTier'].astype('O')
data['OwnCar'] = data['CityTier'].astype('O')
data['ProdTaken'] = data['CityTier'].astype('O')

# %%
num_data=data[[fea for fea in data.columns if data[fea].dtype != 'O']]

# %%
num_data.head()
# Out:
#    CustomerID   Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# 0      200000  41.0              6.0                3.0            1.0
# 1      200001  49.0             14.0                4.0            2.0
# 2      200002  37.0              8.0                4.0            7.0
# 3      200003  33.0              9.0                3.0            2.0
# 4      200004  32.0              8.0                3.0            1.0
#
#    NumberOfChildrenVisiting  MonthlyIncome
# 0                       0.0        20993.0
# 1                       2.0        20130.0
# 2                       0.0        17090.0
# 3                       1.0        17909.0
# 4                       0.0        18468.0

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4879 entries, 0 to 4878
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4879 non-null   int64
#  1   Age                       4879 non-null   float64
#  2   DurationOfPitch           4879 non-null   float64
#  3   NumberOfFollowups         4879 non-null   float64
#  4   NumberOfTrips             4879 non-null   float64
#  5   NumberOfChildrenVisiting  4879 non-null   float64
#  6   MonthlyIncome             4879 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 266.9 KB

# %% [markdown]
# ## Absolute maximum scalling

# %%
from sklearn.preprocessing import MaxAbsScaler as absmax
from sklearn.preprocessing import StandardScaler as ss

# %%
num_absmax = absmax().fit_transform(X=num_data.iloc[:,1:])

# %%
num_absmax
# Out:
# array([[0.67213115, 0.16666667, 0.5       , 0.125     , 0.        ,
#         0.54277736],
#        [0.80327869, 0.38888889, 0.66666667, 0.25      , 0.66666667,
#         0.52046436],
#        [0.60655738, 0.22222222, 0.66666667, 0.875     , 0.        ,
#         0.44186467],
#        ...,
#        [0.85245902, 0.47222222, 0.66666667, 0.875     , 1.        ,
#         0.82271117],
#        [0.31147541, 0.44444444, 0.66666667, 0.375     , 0.66666667,
#         0.52457533],
#        [0.59016393, 0.38888889, 0.66666667, 0.375     , 0.66666667,
#         0.62158389]])

# %%
num_data_absmax = pd.DataFrame(num_absmax,columns=num_data.iloc[:,1:].columns)

# %%
num_data_absmax['CustomerID'] = num_data['CustomerID']
num_data_absmax.set_index('CustomerID',inplace=True)
num_data_absmax
# Out:
#                  Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# CustomerID
# 200000      0.672131         0.166667           0.500000          0.125
# 200001      0.803279         0.388889           0.666667          0.250
# 200002      0.606557         0.222222           0.666667          0.875
# 200003      0.540984         0.250000           0.500000          0.250
# 200004      0.524590         0.222222           0.500000          0.125
# ...              ...              ...                ...            ...
# 204883      0.803279         0.250000           0.833333          0.250
# 204884      0.459016         0.861111           0.833333          0.375
# 204885      0.852459         0.472222           0.666667          0.875
# 204886      0.311475         0.444444           0.666667          0.375
# 204887      0.590164         0.388889           0.666667          0.375
#
#             NumberOfChildrenVisiting  MonthlyIncome
# CustomerID
# 200000                      0.000000       0.542777
# 200001                      0.666667       0.520464
# 200002                      0.000000       0.441865
# 200003                      0.333333       0.463040
# 200004                      0.000000       0.477493
# ...                              ...            ...
# 204883                      0.333333       0.687127
# 204884                      0.666667       0.548440
# 204885                      1.000000       0.822711
# 204886                      0.666667       0.524575
# 204887                      0.666667       0.621584
#
# [4879 rows x 6 columns]

# %% [markdown]
# ## Min-Max scalling

# %%
from sklearn.preprocessing import minmax_scale

# %%
num_minmax = minmax_scale(num_data.iloc[:,1:],feature_range=(0, 1))

# %%
num_data_minmax = pd.DataFrame(num_minmax,columns=num_data.iloc[:,1:].columns)

# %%
num_data_minmax['CustomerID'] = num_data['CustomerID']
num_data_minmax.set_index('CustomerID',inplace=True)
num_data_minmax
# Out:
#                  Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# CustomerID
# 200000      0.534884         0.032258                0.4       0.000000
# 200001      0.720930         0.290323                0.6       0.142857
# 200002      0.441860         0.096774                0.6       0.857143
# 200003      0.348837         0.129032                0.4       0.142857
# 200004      0.325581         0.096774                0.4       0.000000
# ...              ...              ...                ...            ...
# 204883      0.720930         0.129032                0.8       0.142857
# 204884      0.232558         0.838710                0.8       0.285714
# 204885      0.790698         0.387097                0.6       0.857143
# 204886      0.023256         0.354839                0.6       0.285714
# 204887      0.418605         0.290323                0.6       0.285714
#
#             NumberOfChildrenVisiting  MonthlyIncome  CustoomerID
# CustomerID
# 200000                      0.000000       0.479867       200000
# 200001                      0.666667       0.454484       200001
# 200002                      0.000000       0.365070       200002
# 200003                      0.333333       0.389159       200003
# 200004                      0.000000       0.405600       200004
# ...                              ...            ...          ...
# 204883                      0.333333       0.644078       204883
# 204884                      0.666667       0.486308       204884
# 204885                      1.000000       0.798318       204885
# 204886                      0.666667       0.459161       204886
# 204887                      0.666667       0.569517       204887
#
# [4879 rows x 7 columns]

# %% [markdown]
# ## Normalization

# %%
from sklearn import preprocessing

# %%
a = num_data
normalized = preprocessing.normalize(a)

# %%
normalized_num_data = pd.DataFrame(normalized,columns=num_data.columns)

# %%
normalized_num_data
# Out:
#       CustomerID       Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# 0       0.994536  0.000204         0.000030           0.000015       0.000005
# 1       0.994973  0.000244         0.000070           0.000020       0.000010
# 2       0.996369  0.000184         0.000040           0.000020       0.000035
# 3       0.996015  0.000164         0.000045           0.000015       0.000010
# 4       0.995764  0.000159         0.000040           0.000015       0.000005
# ...          ...       ...              ...                ...            ...
# 4874    0.991692  0.000237         0.000044           0.000024       0.000010
# 4875    0.994683  0.000136         0.000151           0.000024       0.000015
# 4876    0.988154  0.000251         0.000082           0.000019       0.000034
# 4877    0.995133  0.000092         0.000078           0.000019       0.000015
# 4878    0.993186  0.000175         0.000068           0.000019       0.000015
#
#       NumberOfChildrenVisiting  MonthlyIncome
# 0                     0.000000       0.104391
# 1                     0.000010       0.100144
# 2                     0.000000       0.085139
# 3                     0.000005       0.089187
# 4                     0.000000       0.091947
# ...                        ...            ...
# 4874                  0.000005       0.128635
# 4875                  0.000010       0.102981
# 4876                  0.000014       0.153467
# 4877                  0.000010       0.098544
# 4878                  0.000010       0.116538
#
# [4879 rows x 7 columns]

# %%
normalized_num_data.drop(columns='CustomerID',axis=1,inplace=True)

# %%
normalized_num_data['CustomerID'] = num_data['CustomerID']

# %%
normalized_num_data.set_index('CustomerID',inplace=True)

# %%
normalized_num_data
# Out:
#                  Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# CustomerID
# 200000      0.000204         0.000030           0.000015       0.000005
# 200001      0.000244         0.000070           0.000020       0.000010
# 200002      0.000184         0.000040           0.000020       0.000035
# 200003      0.000164         0.000045           0.000015       0.000010
# 200004      0.000159         0.000040           0.000015       0.000005
# ...              ...              ...                ...            ...
# 204883      0.000237         0.000044           0.000024       0.000010
# 204884      0.000136         0.000151           0.000024       0.000015
# 204885      0.000251         0.000082           0.000019       0.000034
# 204886      0.000092         0.000078           0.000019       0.000015
# 204887      0.000175         0.000068           0.000019       0.000015
#
#             NumberOfChildrenVisiting  MonthlyIncome
# CustomerID
# 200000                      0.000000       0.104391
# 200001                      0.000010       0.100144
# 200002                      0.000000       0.085139
# 200003                      0.000005       0.089187
# 200004                      0.000000       0.091947
# ...                              ...            ...
# 204883                      0.000005       0.128635
# 204884                      0.000010       0.102981
# 204885                      0.000014       0.153467
# 204886                      0.000010       0.098544
# 204887                      0.000010       0.116538
#
# [4879 rows x 6 columns]

# %% [markdown]
# ## Standardization

# %%
num_data_new = (num_data-num_data.mean())/num_data.std()

# %%
num_data_new.drop(columns='CustomerID',axis=1,inplace=True)

# %%
num_data_new['CustomerID'] = num_data['CustomerID']

# %%
num_data_new.set_index('CustomerID',inplace=True)

# %%
num_data_new
# Out:
#                  Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# CustomerID
# 200000      0.358290        -1.149469          -0.707330      -1.256315
# 200001      1.217465        -0.173080           0.291241      -0.693143
# 200002     -0.071297        -0.905372           0.291241       2.122715
# 200003     -0.500884        -0.783323          -0.707330      -0.693143
# 200004     -0.608281        -0.905372          -0.707330      -1.256315
# ...              ...              ...                ...            ...
# 204883      1.217465        -0.783323           1.289812      -0.693143
# 204884     -1.037868         1.901748           1.289812      -0.129972
# 204885      1.539655         0.193067           0.291241       2.122715
# 204886     -2.004440         0.071018           0.291241      -0.129972
# 204887     -0.178694        -0.173080           0.291241      -0.129972
#
#             NumberOfChildrenVisiting  MonthlyIncome
# CustomerID
# 200000                     -1.386915      -0.491907
# 200001                      0.941632      -0.659379
# 200002                     -1.386915      -1.249315
# 200003                     -0.222641      -1.090382
# 200004                     -1.386915      -0.981903
# ...                              ...            ...
# 204883                     -0.222641       0.591518
# 204884                      0.941632      -0.449408
# 204885                      2.105906       1.609158
# 204886                      0.941632      -0.628524
# 204887                      0.941632       0.099581
#
# [4879 rows x 6 columns]

# %% [markdown]
# ## Robust Scalling

# %%
from sklearn.preprocessing import RobustScaler as robsc

# %%
robsc_transf = robsc().fit(num_data.iloc[:,1:])

# %%
robsc_num_data = pd.DataFrame(robsc_transf.transform(num_data.iloc[:,1:]),columns=num_data.iloc[:,1:].columns)

# %%
robsc_num_data['CustomerID'] = num_data['CustomerID']

# %%
robsc_num_data.set_index('CustomerID',inplace=True)

# %%
robsc_num_data
# Out:
#                  Age  DurationOfPitch  NumberOfFollowups  NumberOfTrips  \
# CustomerID
# 200000      0.384615        -0.636364               -1.0           -1.0
# 200001      1.000000         0.090909                0.0           -0.5
# 200002      0.076923        -0.454545                0.0            2.0
# 200003     -0.230769        -0.363636               -1.0           -0.5
# 200004     -0.307692        -0.454545               -1.0           -1.0
# ...              ...              ...                ...            ...
# 204883      1.000000        -0.363636                1.0           -0.5
# 204884     -0.615385         1.636364                1.0            0.0
# 204885      1.230769         0.363636                0.0            2.0
# 204886     -1.307692         0.272727                0.0            0.0
# 204887      0.000000         0.090909                0.0            0.0
#
#             NumberOfChildrenVisiting  MonthlyIncome
# CustomerID
# 200000                          -1.0      -0.237492
# 200001                           1.0      -0.399512
# 200002                          -1.0      -0.970243
# 200003                           0.0      -0.816484
# 200004                          -1.0      -0.711537
# ...                              ...            ...
# 204883                           0.0       0.810664
# 204884                           1.0      -0.196377
# 204885                           2.0       1.795175
# 204886                           1.0      -0.369661
# 204887                           1.0       0.334741
#
# [4879 rows x 6 columns]

# %% [markdown]
# # Generating CSVs

# %%
os.makedirs('Scalling data')

# %%
num_data_absmax.to_csv('Scalling data/num_data_absmax.csv')

# %%
num_data_minmax.to_csv('Scalling data/num_data_minmax.csv')

# %%
normalized_num_data.to_csv('Scalling data/normalized_num_data.csv')

# %%
num_data_new.to_csv('Scalling data/num_data_new.csv')

# %%
robsc_num_data.to_csv('Scalling data/robsc_num_data.csv')
